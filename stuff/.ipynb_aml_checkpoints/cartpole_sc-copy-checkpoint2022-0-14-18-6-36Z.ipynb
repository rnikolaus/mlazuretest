# %% [markdown]
# ### Prerequisite
# The user should have completed the Azure Machine Learning Tutorial: [Get started creating your first ML experiment with the Python SDK](https://docs.microsoft.com/en-us/azure/machine-learning/tutorial-1st-experiment-sdk-setup). You will need to make sure that you have a valid subscription ID, a resource group, and an Azure Machine Learning workspace. All datastores and datasets you use should be associated with your workspace.

# %% [markdown]
# ## Set up Development Environment
# The following subsections show typical steps to setup your development environment. Setup includes:
#
# * Connecting to a workspace to enable communication between your local machine and remote resources
# * Creating an experiment to track all your runs
# * Creating a remote compute target to use for training

# %% [markdown]
# ### Azure Machine Learning SDK
# Display the Azure Machine Learning SDK version.

# %%
import azureml.core

print("Azure Machine Learning SDK Version:", azureml.core.VERSION)
# Out:
# Azure Machine Learning SDK Version: 1.36.0

# %% [markdown]
# ### Get Azure Machine Learning workspace
# Get a reference to an existing Azure Machine Learning workspace.

# %%
from azureml.core import Workspace

ws = Workspace.from_config()
print(ws.name, ws.location, ws.resource_group, sep = ' | ')
# Out:
# ml-workspace | eastus | ml-rg

# %% [markdown]
# ### Create a new compute resource or attach an existing one
#
# A compute target is a designated compute resource where you run your training and simulation scripts. This location may be your local machine or a cloud-based compute resource. The code below shows how to create a cloud-based compute target. For more information see [What are compute targets in Azure Machine Learning?](https://docs.microsoft.com/en-us/azure/machine-learning/concept-compute-target)
#
# > Note that if you have an AzureML Data Scientist role, you will not have permission to create compute resources. Talk to your workspace or IT admin to create the compute targets described in this section, if they do not already exist.
#
# **Note: Creation of a compute resource can take several minutes**. Please make sure to change `STANDARD_D2_V2` to a [size available in your region](https://azure.microsoft.com/en-us/global-infrastructure/services/?products=virtual-machines).

# %%
from azureml.core.compute import AmlCompute, ComputeTarget
import os

# Choose a name and maximum size for your cluster
compute_name = "cpu-cluster-d2"
compute_min_nodes = 0
compute_max_nodes = 4
vm_size = "STANDARD_D2_V2"

if compute_name in ws.compute_targets:
    print("Found an existing compute target of name: " + compute_name)
    compute_target = ws.compute_targets[compute_name]
    # Note: you may want to make sure compute_target is of type AmlCompute        
else:
    print("Creating new compute target...")
    provisioning_config = AmlCompute.provisioning_configuration(
        vm_size=vm_size,
        min_nodes=compute_min_nodes, 
        max_nodes=compute_max_nodes)
        
    # Create the cluster
    compute_target = ComputeTarget.create(ws, compute_name, provisioning_config)
    compute_target.wait_for_completion(show_output=True, min_node_count=None, timeout_in_minutes=20)

print(compute_target.get_status().serialize())
# Out:
# Creating new compute target...
# InProgress..
# SucceededProvisioning operation finished, operation "Succeeded"
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned
# {'currentNodeCount': 0, 'targetNodeCount': 0, 'nodeStateCounts': {'preparingNodeCount': 0, 'runningNodeCount': 0, 'idleNodeCount': 0, 'unusableNodeCount': 0, 'leavingNodeCount': 0, 'preemptedNodeCount': 0}, 'allocationState': 'Resizing', 'allocationStateTransitionTime': '2022-01-10T21:26:57.336000+00:00', 'errors': None, 'creationTime': '2022-01-10T21:26:56.570879+00:00', 'modifiedTime': '2022-01-10T21:27:03.531588+00:00', 'provisioningState': 'Succeeded', 'provisioningStateTransitionTime': None, 'scaleSettings': {'minNodeCount': 0, 'maxNodeCount': 4, 'nodeIdleTimeBeforeScaleDown': 'PT1800S'}, 'vmPriority': 'Dedicated', 'vmSize': 'STANDARD_D2_V2'}

# %% [markdown]
# ### Create Azure Machine Learning experiment
# Create an experiment to track the runs in your workspace.

# %%
from azureml.core.experiment import Experiment

from files import BCTrade_utils
env ='Btc_with_indicators'
experiment_name = BCTrade_utils.registerBCTrade(env)
exp = Experiment(workspace=ws, name=experiment_name)

# %% [markdown]
# ## Train Cartpole Agent
# To facilitate reinforcement learning, Azure Machine Learning Python SDK provides a high level abstraction, the _ReinforcementLearningEstimator_ class, which allows users to easily construct reinforcement learning run configurations for the underlying reinforcement learning framework. Reinforcement Learning in Azure Machine Learning supports the open source [Ray framework](https://ray.io/) and its highly customizable [RLlib](https://ray.readthedocs.io/en/latest/rllib.html#rllib-scalable-reinforcement-learning). In this section we show how to use _ReinforcementLearningEstimator_ and Ray/RLlib framework to train a cartpole playing agent.

# %% [markdown]
# ### Create reinforcement learning estimator
#
# The code below creates an instance of *ReinforcementLearningEstimator*, `training_estimator`, which then will be used to submit a job to Azure Machine Learning to start the Ray experiment run.
#
# Note that this example is purposely simplified to the minimum. Here is a short description of the parameters we are passing into the constructor:
#
# - `source_directory`, local directory containing your training script(s) and helper modules,
# - `entry_script`, path to your entry script relative to the source directory,
# - `script_params`, constant parameters to be passed to each run of training script,
# - `compute_target`, reference to the compute target in which the trainer and worker(s) jobs will be executed,
# - `rl_framework`, the reinforcement learning framework to be used (currently must be Ray).
#
# We use the `script_params` parameter to pass in general and algorithm-specific parameters to the training script.

# %%
from azureml.contrib.train.rl import ReinforcementLearningEstimator, Ray
from azureml.core.environment import Environment

training_algorithm = "PPO"
rl_environment = env
video_capture = False

algorithm_config = '\'{"num_gpus": 0, "num_workers": 1}\''
#if video_capture:
#    algorithm_config = '\'{"num_gpus": 0, "num_workers": 1, "monitor": true}\''
#else:
#    algorithm_config = '\'{"num_gpus": 0, "num_workers": 1, "monitor": false}\''

script_params = {

    # Training algorithm
    "--run": training_algorithm,
    
    # Training environment
    "--env": rl_environment,
    
    # Algorithm-specific parameters
    "--config": algorithm_config,
    
    # Stop conditions
    "--stop": '\'{"episode_reward_mean": 20, "time_total_s": 36000}\'',
    
    # Frequency of taking checkpoints
    "--checkpoint-freq": 2,
    
    # If a checkpoint should be taken at the end - optional argument with no value
    "--checkpoint-at-end": "",
    
    # Log directory
    "--local-dir": './logs'
}

xvfb_env = None
#if video_capture:
    # Ray's video capture support requires to run everything under a headless display driver called (xvfb).
    # There are two parts to this:
    # 1. Use a custom docker file with proper instructions to install xvfb, ffmpeg, python-opengl
    # and other dependencies.
   
#    with open("files/docker/Dockerfile", "r") as f:
#        dockerfile=f.read()

#    xvfb_env = Environment(name='xvfb-vdisplay')
#    xvfb_env.docker.base_image = None
#    xvfb_env.docker.base_dockerfile = dockerfile
    
    # 2.  Execute the Python process via the xvfb-run command to set up the headless display driver.
#    xvfb_env.python.user_managed_dependencies = True
#    xvfb_env.python.interpreter_path = "xvfb-run -s '-screen 0 640x480x16 -ac +extension GLX +render' python"


training_estimator = ReinforcementLearningEstimator(

    # Location of source files
    source_directory='files',
    
    # Python script file
    entry_script='BCTrade_training.py',
    
    # A dictionary of arguments to pass to the training script specified in ``entry_script``
    script_params=script_params,
    
    # The Azure Machine Learning compute target set up for Ray head nodes
    compute_target=compute_target,
    
    # Reinforcement learning framework. Currently must be Ray.
    rl_framework=Ray(),
    
    # Custom environmnet for Xvfb
    environment=xvfb_env
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-26f6fcb4f6f0> in <module>
#      67
#      68     # The Azure Machine Learning compute target set up for Ray head nodes
# ---> 69     compute_target=compute_target,
#      70
#      71     # Reinforcement learning framework. Currently must be Ray.
#
# NameError: name 'compute_target' is not defined

# %% [markdown]
# ### Training script
#
# As recommended in RLlib documentations, we use Ray Tune API to run the training algorithm. All the RLlib built-in trainers are compatible with the Tune API. Here we use `tune.run()` to execute a built-in training algorithm. For convenience, down below you can see part of the entry script where we make this call.
#
# This is the list of parameters we are passing into `tune.run()` via the `script_params` parameter:
#
# - `run_or_experiment`: name of the [built-in algorithm](https://ray.readthedocs.io/en/latest/rllib-algorithms.html#rllib-algorithms), 'PPO' in our example,
# - `config`: Algorithm-specific configuration. This includes specifying the environment, `env`, which in our example is the gym **[CartPole-v0](https://gym.openai.com/envs/CartPole-v0/)** environment,
# - `stop`: stopping conditions, which could be any of the metrics returned by the trainer. Here we use "mean of episode reward", and "total training time in seconds" as stop conditions, and
# - `checkpoint_freq` and `checkpoint_at_end`: Frequency of taking checkpoints (number of training iterations between checkpoints), and if a checkpoint should be taken at the end.
#
# We also specify the `local_dir`, the directory in which the training logs, checkpoints and other training artificats will be recorded.
#
# See [RLlib Training APIs](https://ray.readthedocs.io/en/latest/rllib-training.html#rllib-training-apis) for more details, and also [Training (tune.run, tune.Experiment)](https://ray.readthedocs.io/en/latest/tune/api_docs/execution.html#training-tune-run-tune-experiment) for the complete list of parameters.
#
# ```python
# import ray
# import ray.tune as tune
#
# if __name__ == "__main__":
#
#     # parse arguments ...
#
#     # Intitialize ray
#     ray.init(address=args.ray_address)
#
#     # Run training task using tune.run
#     tune.run(
#         run_or_experiment=args.run,
#         config=dict(args.config, env=args.env),
#         stop=args.stop,
#         checkpoint_freq=args.checkpoint_freq,
#         checkpoint_at_end=args.checkpoint_at_end,
#         local_dir=args.local_dir
#     )
# ```

# %% [markdown]
# ### Submit the estimator to start experiment
# Now we use the *training_estimator* to submit a run.

# %%
training_run = exp.submit(training_estimator)

# %% [markdown]
# ### Monitor experiment
#
# Azure Machine Learning provides a Jupyter widget to show the status of an experiment run. You could use this widget to monitor the status of the runs.
#
# Note that _ReinforcementLearningEstimator_ creates at least two runs: (a) A parent run, i.e. the run returned above, and (b) a collection of child runs. The number of the child runs depends on the configuration of the reinforcement learning estimator. In our simple scenario, configured above, only one child run will be created.
#
# The widget will show a list of the child runs as well. You can click on the link under **Status** to see the details of a child run. It will also show the metrics being logged.

# %%
from azureml.widgets import RunDetails

RunDetails(training_run).show()
# Out:
# _RLWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', 'sdk_v…

# %% [markdown]
# ### Stop the run
# To stop the run, call `training_run.cancel()`.

# %%
# Uncomment line below to cancel the run
training_run.cancel()

# %% [markdown]
# ### Wait for completion
# Wait for the run to complete before proceeding.
#
# **Note: The length of the run depends on the provisioning time of the compute target and it may take several minutes to complete.**

# %%
training_run.wait_for_completion()
# Out:
# {'runId': 'BCTrade_1640902113_16a527ae',
#  'status': 'Canceled',
#  'startTimeUtc': '2021-12-30T22:12:38.723146Z',
#  'endTimeUtc': '2021-12-30T22:39:29.407457Z',
#  'services': {},
#  'properties': {},
#  'inputDatasets': [],
#  'outputDatasets': [],
#  'logFiles': {'azureml-logs/reinforcementlearning.txt': 'https://rnikolaus.blob.core.windows.net/azureml/ExperimentRun/dcid.BCTrade_1640902113_16a527ae/azureml-logs/reinforcementlearning.txt?sv=2019-07-07&sr=b&sig=WU%2Bsv43vLY46T5273bVk%2BQFgOfDgHwLC%2FTHYTup%2B2cE%3D&skoid=e2479b93-fc73-41fb-89ce-5cfc3e486410&sktid=3ffbf2df-6ac2-41dc-95c5-2f64a8024caf&skt=2021-12-30T12%3A24%3A57Z&ske=2021-12-31T20%3A34%3A57Z&sks=b&skv=2019-07-07&st=2021-12-30T22%3A25%3A05Z&se=2021-12-31T06%3A35%3A05Z&sp=r'},
#  'submittedBy': 'Raphael Nikolaus'}

# %% [markdown]
# ### Get a handle to the child run
# You can obtain a handle to the child run as follows. In our scenario, there is only one child run, we have it called `child_run_0`.

# %%
import time

child_run_0 = None
timeout = 30
while timeout > 0 and not child_run_0:
    child_runs = list(training_run.get_children())
    print('Number of child runs:', len(child_runs))
    if len(child_runs) > 0:
        child_run_0 = child_runs[0]
        break
    time.sleep(2) # Wait for 2 seconds
    timeout -= 2

print('Child run info:')
print(child_run_0)
# Out:
# Number of child runs: 1
# Child run info:
# Run(Experiment: BCTrade-Btc_with_indicators,
# Id: BCTrade-Btc_with_indicators_1641752441_311b6d75_head,
# Type: azureml.scriptrun,
# Status: Canceled)

# %% [markdown]
# ### Get access to training artifacts
# We can simply use run id to get a handle to an in-progress or a previously concluded run.

# %%
from azureml.core import Run

#run_id = child_run_0.id # Or set to run id of a completed run (e.g. 'rl-cartpole-v0_1587572312_06e04ace_head')
run_id = 'BCTrade-Btc_with_indicators_1641850079_8e229836_head'
child_run_0 = Run(exp, run_id=run_id)
#child_run_0.get_environment()

# %% [markdown]
# Now we can use the Run API to download policy training artifacts (saved model and checkpoints) to local compute.

# %%
from os import path
from distutils import dir_util

training_artifacts_path = path.join("logs", training_algorithm)
print("Training artifacts path:", training_artifacts_path)

if path.exists(training_artifacts_path):
    dir_util.remove_tree(training_artifacts_path)

# Download run artifacts to local compute
child_run_0.download_files(training_artifacts_path)
# Out:
# Training artifacts path: logs/PPO

# %% [markdown]
# ## Evaluate Trained Agent and See Results
#
# We can evaluate a previously trained policy using the `rollout.py` helper script provided by RLlib (see [Evaluating Trained Policies](https://ray.readthedocs.io/en/latest/rllib-training.html#evaluating-trained-policies) for more details). Here we use an adaptation of this script to reconstruct a policy from a checkpoint taken and saved during training. We took these checkpoints by setting `checkpoint-freq` and `checkpoint-at-end` parameters above.
# In this section we show how to use these checkpoints to evaluate the trained policy.

# %% [markdown]
# ### Evaluate a trained policy
# We need to configure another reinforcement learning estimator, `rollout_estimator`, and then use it to submit another run. Note that the entry script for this estimator now points to `cartpole-rollout.py` script.
# Also note how we pass the checkpoints dataset to this script using `inputs` parameter of the _ReinforcementLearningEstimator_.
#
# We are using script parameters to pass in the same algorithm and the same environment used during training. We also specify the checkpoint number of the checkpoint we wish to evaluate, `checkpoint-number`, and number of the steps we shall run the rollout, `steps`.
#
# The training artifacts dataset will be accessible to the rollout script as a mounted folder. The mounted folder and the checkpoint number, passed in via `checkpoint-number`, will be used to create a path to the checkpoint we are going to evaluate. The created checkpoint path then will be passed into RLlib rollout script for evaluation.
#
# Let's find the checkpoints and the last checkpoint number first.

# %%
# A helper function to find checkpoint files in a directory
def find_checkpoints(file_path):
    print("Looking in path:", file_path)
    checkpoints = []
    for root, _, files in os.walk(file_path):
        for name in files:
            if os.path.basename(root).startswith('checkpoint_'):
                checkpoints.append(path.join(root, name))
    return checkpoints

checkpoint_files = find_checkpoints(training_artifacts_path)
# Out:
# Looking in path: logs/PPO

# %%
# Find checkpoints and last checkpoint number
checkpoint_numbers = []
for file in checkpoint_files:
    file = os.path.basename(file)
    if file.startswith('checkpoint-') and not file.endswith('.tune_metadata'):
        checkpoint_numbers.append(int(file.split('-')[-1]))

print("Checkpoints:", checkpoint_numbers)

last_checkpoint_number = max(checkpoint_numbers)
print("Last checkpoint number:", last_checkpoint_number)
# Out:
# Checkpoints: [10, 100, 102, 104, 106, 108, 110, 112, 114, 116, 118, 12, 120, 122, 124, 126, 128, 130, 132, 134, 136, 138, 14, 140, 142, 144, 146, 148, 150, 152, 154, 156, 158, 16, 160, 162, 164, 166, 168, 170, 172, 174, 176, 178, 18, 180, 182, 184, 186, 188, 190, 192, 194, 196, 198, 2, 20, 200, 202, 204, 206, 208, 210, 212, 214, 216, 218, 22, 220, 222, 224, 226, 228, 230, 232, 234, 236, 238, 24, 240, 242, 244, 246, 248, 250, 252, 254, 256, 258, 26, 260, 262, 264, 266, 268, 270, 272, 274, 276, 278, 28, 280, 282, 284, 286, 288, 290, 292, 294, 296, 298, 30, 300, 302, 304, 306, 308, 310, 312, 314, 316, 318, 32, 320, 322, 324, 326, 328, 330, 332, 334, 336, 338, 34, 340, 342, 344, 346, 348, 350, 352, 354, 356, 358, 36, 360, 362, 364, 366, 368, 370, 372, 374, 376, 378, 38, 380, 382, 384, 386, 388, 390, 392, 394, 396, 398, 4, 40, 400, 402, 404, 406, 408, 410, 412, 414, 416, 418, 42, 420, 422, 424, 426, 428, 430, 432, 434, 436, 438, 44, 440, 442, 444, 446, 448, 450, 452, 454, 456, 458, 46, 460, 462, 464, 466, 468, 470, 472, 474, 476, 478, 48, 480, 482, 484, 486, 488, 490, 492, 494, 496, 498, 50, 500, 502, 504, 506, 508, 510, 512, 514, 516, 518, 52, 520, 522, 524, 526, 528, 530, 532, 534, 536, 538, 54, 540, 542, 544, 546, 548, 550, 552, 554, 556, 558, 56, 560, 562, 564, 566, 568, 570, 572, 574, 576, 578, 58, 580, 582, 584, 586, 588, 590, 592, 594, 596, 598, 6, 60, 600, 602, 604, 606, 608, 610, 612, 614, 616, 618, 62, 620, 622, 624, 626, 628, 630, 632, 634, 636, 638, 64, 640, 642, 644, 646, 648, 650, 652, 654, 656, 658, 66, 660, 662, 664, 666, 668, 670, 672, 674, 676, 678, 68, 680, 682, 684, 686, 688, 690, 692, 694, 696, 698, 70, 700, 702, 704, 706, 708, 710, 712, 714, 716, 718, 72, 720, 722, 724, 726, 728, 730, 732, 734, 736, 738, 74, 740, 742, 744, 746, 748, 750, 752, 754, 756, 758, 76, 760, 762, 764, 766, 768, 770, 772, 774, 776, 778, 78, 780, 782, 784, 786, 788, 790, 792, 794, 796, 798, 8, 80, 800, 802, 804, 806, 808, 810, 812, 814, 816, 818, 82, 820, 822, 84, 86, 88, 90, 92, 94, 96, 98]
# Last checkpoint number: 822

# %%
# Upload the checkpoint files and create a DataSet
from azureml.core import Dataset

datastore = ws.get_default_datastore()
checkpoint_dataref = datastore.upload_files(checkpoint_files, target_path='checkpoints_' + run_id, overwrite=True)
checkpoint_ds = Dataset.File.from_files(checkpoint_dataref)
# Out:
# Uploading an estimated of 866 files
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_10/checkpoint-10.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_10/checkpoint-10.tune_metadata, 1 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_100/checkpoint-100
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_100/checkpoint-100, 2 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_100/checkpoint-100.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_100/checkpoint-100.tune_metadata, 3 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_102/checkpoint-102.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_102/checkpoint-102.tune_metadata, 4 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_106/checkpoint-106
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_106/checkpoint-106, 5 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_106/checkpoint-106.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_106/checkpoint-106.tune_metadata, 6 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_108/checkpoint-108
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_108/checkpoint-108, 7 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_108/checkpoint-108.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_108/checkpoint-108.tune_metadata, 8 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_110/checkpoint-110
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_110/checkpoint-110, 9 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_110/checkpoint-110.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_110/checkpoint-110.tune_metadata, 10 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_112/checkpoint-112.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_112/checkpoint-112.tune_metadata, 11 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_114/checkpoint-114
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_114/checkpoint-114, 12 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_114/checkpoint-114.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_114/checkpoint-114.tune_metadata, 13 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_116/checkpoint-116
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_116/checkpoint-116, 14 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_116/checkpoint-116.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_116/checkpoint-116.tune_metadata, 15 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_118/checkpoint-118.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_118/checkpoint-118.tune_metadata, 16 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_10/checkpoint-10
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_10/checkpoint-10, 17 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_102/checkpoint-102
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_102/checkpoint-102, 18 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_104/checkpoint-104
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_104/checkpoint-104, 19 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_112/checkpoint-112
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_112/checkpoint-112, 20 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_118/checkpoint-118
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_118/checkpoint-118, 21 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_12/checkpoint-12
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_12/checkpoint-12, 22 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_12/checkpoint-12.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_12/checkpoint-12.tune_metadata, 23 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_120/checkpoint-120
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_120/checkpoint-120, 24 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_120/checkpoint-120.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_120/checkpoint-120.tune_metadata, 25 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_122/checkpoint-122
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_122/checkpoint-122, 26 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_122/checkpoint-122.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_122/checkpoint-122.tune_metadata, 27 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_124/checkpoint-124
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_124/checkpoint-124, 28 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_124/checkpoint-124.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_124/checkpoint-124.tune_metadata, 29 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_126/checkpoint-126
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_126/checkpoint-126, 30 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_126/checkpoint-126.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_126/checkpoint-126.tune_metadata, 31 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_128/checkpoint-128
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_128/checkpoint-128, 32 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_128/checkpoint-128.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_128/checkpoint-128.tune_metadata, 33 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_130/checkpoint-130
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_130/checkpoint-130, 34 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_130/checkpoint-130.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_130/checkpoint-130.tune_metadata, 35 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_132/checkpoint-132.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_132/checkpoint-132.tune_metadata, 36 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_136/checkpoint-136
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_136/checkpoint-136, 37 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_136/checkpoint-136.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_136/checkpoint-136.tune_metadata, 38 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_138/checkpoint-138
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_138/checkpoint-138, 39 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_14/checkpoint-14
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_14/checkpoint-14, 40 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_14/checkpoint-14.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_14/checkpoint-14.tune_metadata, 41 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_140/checkpoint-140
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_140/checkpoint-140, 42 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_140/checkpoint-140.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_140/checkpoint-140.tune_metadata, 43 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_142/checkpoint-142
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_142/checkpoint-142, 44 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_104/checkpoint-104.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_104/checkpoint-104.tune_metadata, 45 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_132/checkpoint-132
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_132/checkpoint-132, 46 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_134/checkpoint-134
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_134/checkpoint-134, 47 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_134/checkpoint-134.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_134/checkpoint-134.tune_metadata, 48 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_138/checkpoint-138.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_138/checkpoint-138.tune_metadata, 49 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_142/checkpoint-142.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_142/checkpoint-142.tune_metadata, 50 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_144/checkpoint-144
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_144/checkpoint-144, 51 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_144/checkpoint-144.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_144/checkpoint-144.tune_metadata, 52 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_146/checkpoint-146
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_146/checkpoint-146, 53 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_146/checkpoint-146.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_146/checkpoint-146.tune_metadata, 54 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_148/checkpoint-148
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_148/checkpoint-148, 55 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_148/checkpoint-148.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_148/checkpoint-148.tune_metadata, 56 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_152/checkpoint-152
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_152/checkpoint-152, 57 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_152/checkpoint-152.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_152/checkpoint-152.tune_metadata, 58 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_154/checkpoint-154
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_154/checkpoint-154, 59 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_154/checkpoint-154.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_154/checkpoint-154.tune_metadata, 60 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_156/checkpoint-156
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_156/checkpoint-156, 61 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_156/checkpoint-156.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_156/checkpoint-156.tune_metadata, 62 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_158/checkpoint-158.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_158/checkpoint-158.tune_metadata, 63 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_16/checkpoint-16
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_16/checkpoint-16, 64 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_16/checkpoint-16.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_16/checkpoint-16.tune_metadata, 65 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_160/checkpoint-160
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_160/checkpoint-160, 66 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_164/checkpoint-164.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_164/checkpoint-164.tune_metadata, 67 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_166/checkpoint-166.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_166/checkpoint-166.tune_metadata, 68 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_150/checkpoint-150
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_150/checkpoint-150, 69 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_150/checkpoint-150.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_150/checkpoint-150.tune_metadata, 70 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_158/checkpoint-158
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_158/checkpoint-158, 71 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_160/checkpoint-160.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_160/checkpoint-160.tune_metadata, 72 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_162/checkpoint-162
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_162/checkpoint-162, 73 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_162/checkpoint-162.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_162/checkpoint-162.tune_metadata, 74 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_164/checkpoint-164
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_164/checkpoint-164, 75 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_168/checkpoint-168
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_168/checkpoint-168, 76 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_168/checkpoint-168.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_168/checkpoint-168.tune_metadata, 77 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_170/checkpoint-170
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_170/checkpoint-170, 78 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_170/checkpoint-170.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_170/checkpoint-170.tune_metadata, 79 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_172/checkpoint-172
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_172/checkpoint-172, 80 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_172/checkpoint-172.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_172/checkpoint-172.tune_metadata, 81 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_174/checkpoint-174
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_174/checkpoint-174, 82 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_174/checkpoint-174.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_174/checkpoint-174.tune_metadata, 83 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_176/checkpoint-176
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_176/checkpoint-176, 84 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_176/checkpoint-176.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_176/checkpoint-176.tune_metadata, 85 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_178/checkpoint-178
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_178/checkpoint-178, 86 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_178/checkpoint-178.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_178/checkpoint-178.tune_metadata, 87 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_18/checkpoint-18
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_18/checkpoint-18, 88 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_18/checkpoint-18.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_18/checkpoint-18.tune_metadata, 89 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_180/checkpoint-180.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_180/checkpoint-180.tune_metadata, 90 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_188/checkpoint-188
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_188/checkpoint-188, 91 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_192/checkpoint-192
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_192/checkpoint-192, 92 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_192/checkpoint-192.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_192/checkpoint-192.tune_metadata, 93 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_194/checkpoint-194
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_194/checkpoint-194, 94 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_166/checkpoint-166
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_166/checkpoint-166, 95 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_180/checkpoint-180
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_180/checkpoint-180, 96 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_182/checkpoint-182
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_182/checkpoint-182, 97 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_182/checkpoint-182.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_182/checkpoint-182.tune_metadata, 98 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_184/checkpoint-184
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_184/checkpoint-184, 99 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_184/checkpoint-184.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_184/checkpoint-184.tune_metadata, 100 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_186/checkpoint-186
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_186/checkpoint-186, 101 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_186/checkpoint-186.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_186/checkpoint-186.tune_metadata, 102 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_188/checkpoint-188.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_188/checkpoint-188.tune_metadata, 103 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_190/checkpoint-190
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_190/checkpoint-190, 104 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_190/checkpoint-190.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_190/checkpoint-190.tune_metadata, 105 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_194/checkpoint-194.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_194/checkpoint-194.tune_metadata, 106 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_196/checkpoint-196
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_196/checkpoint-196, 107 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_196/checkpoint-196.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_196/checkpoint-196.tune_metadata, 108 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_198/checkpoint-198
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_198/checkpoint-198, 109 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_198/checkpoint-198.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_198/checkpoint-198.tune_metadata, 110 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_2/checkpoint-2
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_2/checkpoint-2, 111 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_2/checkpoint-2.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_2/checkpoint-2.tune_metadata, 112 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_20/checkpoint-20
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_20/checkpoint-20, 113 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_20/checkpoint-20.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_20/checkpoint-20.tune_metadata, 114 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_200/checkpoint-200
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_200/checkpoint-200, 115 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_200/checkpoint-200.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_200/checkpoint-200.tune_metadata, 116 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_202/checkpoint-202
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_202/checkpoint-202, 117 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_202/checkpoint-202.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_202/checkpoint-202.tune_metadata, 118 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_204/checkpoint-204
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_204/checkpoint-204, 119 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_208/checkpoint-208.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_208/checkpoint-208.tune_metadata, 120 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_210/checkpoint-210
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_210/checkpoint-210, 121 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_212/checkpoint-212.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_212/checkpoint-212.tune_metadata, 122 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_214/checkpoint-214
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_214/checkpoint-214, 123 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_216/checkpoint-216
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_216/checkpoint-216, 124 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_216/checkpoint-216.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_216/checkpoint-216.tune_metadata, 125 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_220/checkpoint-220.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_220/checkpoint-220.tune_metadata, 126 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_204/checkpoint-204.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_204/checkpoint-204.tune_metadata, 127 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_206/checkpoint-206
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_206/checkpoint-206, 128 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_206/checkpoint-206.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_206/checkpoint-206.tune_metadata, 129 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_208/checkpoint-208
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_208/checkpoint-208, 130 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_210/checkpoint-210.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_210/checkpoint-210.tune_metadata, 131 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_212/checkpoint-212
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_212/checkpoint-212, 132 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_214/checkpoint-214.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_214/checkpoint-214.tune_metadata, 133 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_218/checkpoint-218
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_218/checkpoint-218, 134 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_218/checkpoint-218.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_218/checkpoint-218.tune_metadata, 135 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_22/checkpoint-22
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_22/checkpoint-22, 136 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_22/checkpoint-22.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_22/checkpoint-22.tune_metadata, 137 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_220/checkpoint-220
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_220/checkpoint-220, 138 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_222/checkpoint-222
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_222/checkpoint-222, 139 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_222/checkpoint-222.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_222/checkpoint-222.tune_metadata, 140 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_224/checkpoint-224
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_224/checkpoint-224, 141 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_224/checkpoint-224.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_224/checkpoint-224.tune_metadata, 142 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_226/checkpoint-226.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_226/checkpoint-226.tune_metadata, 143 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_228/checkpoint-228
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_228/checkpoint-228, 144 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_228/checkpoint-228.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_228/checkpoint-228.tune_metadata, 145 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_230/checkpoint-230
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_230/checkpoint-230, 146 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_232/checkpoint-232
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_232/checkpoint-232, 147 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_232/checkpoint-232.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_232/checkpoint-232.tune_metadata, 148 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_234/checkpoint-234
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_234/checkpoint-234, 149 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_234/checkpoint-234.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_234/checkpoint-234.tune_metadata, 150 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_236/checkpoint-236
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_236/checkpoint-236, 151 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_236/checkpoint-236.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_236/checkpoint-236.tune_metadata, 152 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_238/checkpoint-238
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_238/checkpoint-238, 153 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_24/checkpoint-24.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_24/checkpoint-24.tune_metadata, 154 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_240/checkpoint-240.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_240/checkpoint-240.tune_metadata, 155 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_242/checkpoint-242
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_242/checkpoint-242, 156 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_242/checkpoint-242.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_242/checkpoint-242.tune_metadata, 157 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_244/checkpoint-244.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_244/checkpoint-244.tune_metadata, 158 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_226/checkpoint-226
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_226/checkpoint-226, 159 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_230/checkpoint-230.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_230/checkpoint-230.tune_metadata, 160 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_238/checkpoint-238.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_238/checkpoint-238.tune_metadata, 161 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_24/checkpoint-24
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_24/checkpoint-24, 162 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_244/checkpoint-244
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_244/checkpoint-244, 163 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_246/checkpoint-246
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_246/checkpoint-246, 164 files out of an estimated total of 866
# ...
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_828/checkpoint-828.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_828/checkpoint-828.tune_metadata, 815 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_832/checkpoint-832
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_832/checkpoint-832, 816 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_832/checkpoint-832.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_832/checkpoint-832.tune_metadata, 817 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_834/checkpoint-834
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_834/checkpoint-834, 818 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_836/checkpoint-836
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_836/checkpoint-836, 819 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_836/checkpoint-836.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_836/checkpoint-836.tune_metadata, 820 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_838/checkpoint-838
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_838/checkpoint-838, 821 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_838/checkpoint-838.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_838/checkpoint-838.tune_metadata, 822 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_84/checkpoint-84
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_84/checkpoint-84, 823 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_84/checkpoint-84.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_84/checkpoint-84.tune_metadata, 824 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_840/checkpoint-840.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_840/checkpoint-840.tune_metadata, 825 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_842/checkpoint-842
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_842/checkpoint-842, 826 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_842/checkpoint-842.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_842/checkpoint-842.tune_metadata, 827 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_844/checkpoint-844
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_844/checkpoint-844, 828 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_844/checkpoint-844.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_844/checkpoint-844.tune_metadata, 829 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_846/checkpoint-846
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_846/checkpoint-846, 830 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_846/checkpoint-846.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_846/checkpoint-846.tune_metadata, 831 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_848/checkpoint-848
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_848/checkpoint-848, 832 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_848/checkpoint-848.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_848/checkpoint-848.tune_metadata, 833 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_850/checkpoint-850
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_850/checkpoint-850, 834 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_850/checkpoint-850.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_850/checkpoint-850.tune_metadata, 835 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_854/checkpoint-854
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_854/checkpoint-854, 836 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_854/checkpoint-854.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_854/checkpoint-854.tune_metadata, 837 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_856/checkpoint-856.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_856/checkpoint-856.tune_metadata, 838 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_858/checkpoint-858.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_858/checkpoint-858.tune_metadata, 839 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_86/checkpoint-86
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_86/checkpoint-86, 840 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_864/checkpoint-864.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_864/checkpoint-864.tune_metadata, 841 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_840/checkpoint-840
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_840/checkpoint-840, 842 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_852/checkpoint-852
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_852/checkpoint-852, 843 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_852/checkpoint-852.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_852/checkpoint-852.tune_metadata, 844 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_856/checkpoint-856
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_856/checkpoint-856, 845 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_858/checkpoint-858
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_858/checkpoint-858, 846 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_86/checkpoint-86.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_86/checkpoint-86.tune_metadata, 847 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_860/checkpoint-860.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_860/checkpoint-860.tune_metadata, 848 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_862/checkpoint-862
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_862/checkpoint-862, 849 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_862/checkpoint-862.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_862/checkpoint-862.tune_metadata, 850 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_864/checkpoint-864
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_864/checkpoint-864, 851 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_866/checkpoint-866
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_866/checkpoint-866, 852 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_866/checkpoint-866.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_866/checkpoint-866.tune_metadata, 853 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_88/checkpoint-88
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_88/checkpoint-88, 854 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_88/checkpoint-88.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_88/checkpoint-88.tune_metadata, 855 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_90/checkpoint-90
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_90/checkpoint-90, 856 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_90/checkpoint-90.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_90/checkpoint-90.tune_metadata, 857 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_92/checkpoint-92
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_92/checkpoint-92, 858 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_92/checkpoint-92.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_92/checkpoint-92.tune_metadata, 859 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_94/checkpoint-94.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_94/checkpoint-94.tune_metadata, 860 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_96/checkpoint-96
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_96/checkpoint-96, 861 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_96/checkpoint-96.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_96/checkpoint-96.tune_metadata, 862 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_98/checkpoint-98
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_98/checkpoint-98, 863 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_98/checkpoint-98.tune_metadata
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_98/checkpoint-98.tune_metadata, 864 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_860/checkpoint-860
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_860/checkpoint-860, 865 files out of an estimated total of 866
# Uploading logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_94/checkpoint-94
# Uploaded logs/PPO/PPO_BCTrade-Btc_with_indicators_78880bdc_2022-01-08_18-11-59g5a4da7x/checkpoint_94/checkpoint-94, 866 files out of an estimated total of 866
# Uploaded 866 files
# Error in atexit._run_exitfuncs:
# Traceback (most recent call last):
#   File "/anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/dataprep/api/engineapi/engine.py", line 275, in send_message
#     raise message['error']
#   File "/anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/dataprep/api/engineapi/engine.py", line 223, in process_responses
#     response = self._read_response(caller='MultiThreadMessageChannel.process_responses')
#   File "/anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/dataprep/api/engineapi/engine.py", line 148, in _read_response
#     raise error
# RuntimeError: Engine process terminated. Please try running again. |session_id=f018534c-2eb2-4051-beff-4a75ca6caf99

# %% [markdown]
# Now let's configure rollout estimator. Note that we use the last checkpoint for evaluation. The assumption is that the last checkpoint points to our best trained agent. You may change this to any of the checkpoint numbers printed above and observe the effect.

# %%
script_params = {    
    # Checkpoint number of the checkpoint from which to roll out
    "--checkpoint-number": last_checkpoint_number,

    # Training algorithm
    "--run": training_algorithm,
    
    # Training environment
    "--env": rl_environment,
    
    # Algorithm-specific parameters
    "--config": '{}',
    
    # Number of rollout steps 
    "--steps": 2000,
    
    # If should repress rendering of the environment
    "--no-render": "",
    
    # The place where recorded videos will be stored
    "--video-dir": "./logs/video"
}

if video_capture:
    script_params.pop("--no-render")
else:
    script_params.pop("--video-dir")


# Ray's video capture support requires to run everything under a headless display driver called (xvfb).
# There are two parts to this:

# 1. Use a custom docker file with proper instructions to install xvfb, ffmpeg, python-opengl
# and other dependencies.
# Note: Even when the rendering is off pyhton-opengl is needed.

#with open("files/docker/Dockerfile", "r") as f:
#    dockerfile=f.read()

#xvfb_env = Environment(name='xvfb-vdisplay')
#xvfb_env.docker.base_image = None
#xvfb_env.docker.base_dockerfile = dockerfile
    
# 2.  Execute the Python process via the xvfb-run command to set up the headless display driver.
#xvfb_env.python.user_managed_dependencies = True
#if video_capture:
#    xvfb_env.python.interpreter_path = "xvfb-run -s '-screen 0 640x480x16 -ac +extension GLX +render' python"


rollout_estimator = ReinforcementLearningEstimator(
    # Location of source files
    source_directory='files',
    
    # Python script file
    entry_script='BCTrade_rollout.py',
    
    # A dictionary of arguments to pass to the rollout script specified in ``entry_script``
    script_params = script_params,
    
    # Data inputs
    inputs=[
        checkpoint_ds.as_named_input('artifacts_dataset'),
        checkpoint_ds.as_named_input('artifacts_path').as_mount()],
    
    # The Azure Machine Learning compute target set up for Ray head nodes
    compute_target=compute_target,
    
    # Reinforcement learning framework. Currently must be Ray.
    rl_framework=Ray(),
    
    # Custom environmnet for Xvfb
    environment=xvfb_env)

# %% [markdown]
# Same as before, we use the *rollout_estimator* to submit a run.

# %%
rollout_run = exp.submit(rollout_estimator)

# %% [markdown]
# And then, similar to the training section, we can monitor the real-time progress of the rollout run and its chid as follows. If you browse logs of the child run you can see the evaluation results recorded in driver_log.txt file. Note that you may need to wait several minutes before these results become available.

# %%
RunDetails(rollout_run).show()
# Out:
# _RLWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', 'sdk_v…
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/ipywidgets/widgets/widget.py in _handle_msg(self, msg)
#     674                 if 'buffer_paths' in data:
#     675                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 676                 self.set_state(state)
#     677
#     678         # Handle a state request.
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/ipywidgets/widgets/widget.py in set_state(self, sync_data)
#     543                     from_json = self.trait_metadata(name, 'from_json',
#     544                                                     self._trait_from_json)
# --> 545                     self.set_trait(name, from_json(sync_data[name], self))
#     546
#     547     def send(self, content, buffers=None):
#
# /anaconda/envs/azureml_py36/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      86         if type is None:
#      87             try:
# ---> 88                 next(self.gen)
#      89             except StopIteration:
#      90                 return False
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/traitlets/traitlets.py in hold_trait_notifications(self)
#    1129                 for changes in cache.values():
#    1130                     for change in changes:
# -> 1131                         self.notify_change(change)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/widgets/_userrun/_run_details.py in _on_selected_run_log_change(self, change)
#     622     def _on_selected_run_log_change(self, change):
#     623         self.selected_run_log = change.new
# --> 624         self._get_run_logs_async(self.widget_instance.run_properties['log_files'],
#     625                                  self.widget_instance.run_properties['status'],
#     626                                  self.error, change.new)
#
# KeyError: 'log_files'

# %% [markdown]
# Wait for completion of the rollout run before moving to the next section, or you may cancel the run.

# %%
# Uncomment line below to cancel the run
#rollout_run.cancel()
rollout_run.wait_for_completion()
# Out:
# {'runId': 'BCTrade_1640904104_262fc15a',
#  'status': 'Finalizing',
#  'startTimeUtc': '2021-12-30T22:42:23.225849Z',
#  'services': {},
#  'properties': {},
#  'inputDatasets': [],
#  'outputDatasets': [],
#  'logFiles': {'azureml-logs/reinforcementlearning.txt': 'https://rnikolaus.blob.core.windows.net/azureml/ExperimentRun/dcid.BCTrade_1640904104_262fc15a/azureml-logs/reinforcementlearning.txt?sv=2019-07-07&sr=b&sig=NmkQMKN%2B7cgcPyuy0rRIsiohVyuPLutuSshX%2F7b1CQs%3D&skoid=e2479b93-fc73-41fb-89ce-5cfc3e486410&sktid=3ffbf2df-6ac2-41dc-95c5-2f64a8024caf&skt=2021-12-30T12%3A18%3A27Z&ske=2021-12-31T20%3A28%3A27Z&sks=b&skv=2019-07-07&st=2021-12-30T22%3A32%3A05Z&se=2021-12-31T06%3A42%3A05Z&sp=r'},
#  'submittedBy': 'Raphael Nikolaus'}

# %% [markdown]
# ### Display movies of selected rollout episodes
#
# To display recorded movies first we download recorded videos to local machine. Here again we create a dataset of rollout artifacts and use the helper functions introduced above to download and displays rollout videos.

# %%
# Get a handle to child run
child_runs = list(rollout_run.get_children())
print('Number of child runs:', len(child_runs))
child_run_0 = child_runs[0]

# Download rollout artifacts
rollout_artifacts_path = path.join("logs", "rollout")
print("Rollout artifacts path:", rollout_artifacts_path)

if path.exists(rollout_artifacts_path):
    dir_util.remove_tree(rollout_artifacts_path)

# Download videos to local compute
child_run_0.download_files("logs/video", output_directory = rollout_artifacts_path)

# %% [markdown]
# ## Cleaning up
# For your convenience, below you can find code snippets to clean up any resources created as part of this tutorial that you don't wish to retain.

# %%
# To archive the created experiment:
#exp.archive()

# To delete the compute target:
#compute_target.delete()

# To delete downloaded training artifacts
#if os.path.exists(training_artifacts_path):
#    dir_util.remove_tree(training_artifacts_path)

# To delete downloaded rollout videos
#if path.exists(rollout_artifacts_path):
#    dir_util.remove_tree(rollout_artifacts_path)

# %% [markdown]
# ## Next
# This example was about running Reinforcement Learning in Azure Machine Learning (Ray/RLlib Framework) on a single compute. Please see [Pong Problem](../atari-on-distributed-compute/pong_rllib.ipynb)
# example which uses Ray RLlib to train a Pong playing agent on a multi-node cluster.
